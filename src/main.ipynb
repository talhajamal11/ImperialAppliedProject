# %%
from main import PriceSimulator
import numpy as np

# %%
simulator = PriceSimulator(initial_price=100, mu=0.0001, sigma=0.25, dt=1, seed=50)
prices = simulator.simulate_brownian_motion_prices()
price_df = simulator.create_dataframe(prices)
simulator.plot_prices()
# Out:
# -- Generating Trading Days --
# -- Generating Time Series --
#          date      time       price  tick_by_tick_return
# 0  2023-01-02  00:00:00  100.000000             0.000000
# 1  2023-01-02  00:01:00   99.609912            -0.003901
# 2  2023-01-02  00:02:00   99.602168            -0.000078
# 3  2023-01-02  00:03:00   99.446935            -0.001559
# 4  2023-01-02  00:04:00   99.080790            -0.003682
#               date      time       price  tick_by_tick_return
# 120955  2023-12-19  07:55:00  249.696561             0.001337
# 120956  2023-12-19  07:56:00  249.910400             0.000856
# 120957  2023-12-19  07:57:00  249.882657            -0.000111
# 120958  2023-12-19  07:58:00  249.826809            -0.000223
# 120959  2023-12-19  07:59:00  249.979485             0.000611

# %%
price_df
# Out:
#               date      time       price  tick_by_tick_return
# 0       2023-01-02  00:00:00  100.000000             0.000000
# 1       2023-01-02  00:01:00   99.609912            -0.003901
# 2       2023-01-02  00:02:00   99.602168            -0.000078
# 3       2023-01-02  00:03:00   99.446935            -0.001559
# 4       2023-01-02  00:04:00   99.080790            -0.003682
# ...            ...       ...         ...                  ...
# 120955  2023-12-19  07:55:00  249.696561             0.001337
# 120956  2023-12-19  07:56:00  249.910400             0.000856
# 120957  2023-12-19  07:57:00  249.882657            -0.000111
# 120958  2023-12-19  07:58:00  249.826809            -0.000223
# 120959  2023-12-19  07:59:00  249.979485             0.000611
#
# [120960 rows x 4 columns]

# %%
((price_df["price"].iloc[-1] - price_df["price"].iloc[0]) / price_df["price"].iloc[0] ) * 100
# Out:
# np.float64(149.97948485389486)

# %%
compounded_return = (1 + price_df['tick_by_tick_return']).cumprod() - 1
compounded_return
# Out:
# 0         0.000000
# 1        -0.003901
# 2        -0.003978
# 3        -0.005531
# 4        -0.009192
#             ...
# 120955    1.496966
# 120956    1.499104
# 120957    1.498827
# 120958    1.498268
# 120959    1.499795
# Name: tick_by_tick_return, Length: 120960, dtype: float64

# %%
aggressiveness_values = np.random.uniform(0, 1, 90)

# %%
aggressiveness_values
# Out:
# array([9.35264497e-02, 2.88925455e-01, 4.54631147e-01, 6.97602817e-02,
#        6.73994184e-01, 3.79861867e-02, 5.40495503e-01, 2.32845063e-01,
#        2.32990844e-01, 8.47867958e-01, 4.32752074e-01, 6.48590933e-02,
#        9.67424095e-01, 8.50351120e-01, 2.50772984e-01, 5.76156336e-01,
#        4.16828274e-04, 7.57175386e-01, 3.91543207e-01, 2.42797963e-01,
#        7.37095461e-01, 7.33669176e-01, 8.45041730e-01, 5.40621139e-01,
#        4.00991733e-01, 9.31903097e-01, 4.39167832e-01, 8.81832102e-01,
#        1.96810828e-01, 3.40162573e-02, 1.05316489e-01, 6.33666755e-01,
#        6.37552216e-01, 2.85566174e-01, 1.03402797e-01, 8.48145193e-01,
#        8.28013118e-01, 6.44165570e-02, 5.29121888e-01, 5.89525700e-01,
#        1.60701023e-01, 8.84443873e-02, 7.22156089e-01, 3.35919534e-01,
#        9.63093714e-01, 1.01110672e-01, 7.91658366e-01, 4.21804555e-02,
#        7.11453858e-01, 9.80855848e-01, 2.93715804e-01, 3.81714739e-01,
#        1.44628704e-01, 3.53180131e-01, 6.85964036e-01, 1.62894509e-01,
#        9.89911518e-01, 7.83566697e-01, 2.72813501e-01, 2.69616274e-01,
#        8.34356039e-01, 4.19185881e-01, 9.65426157e-01, 3.20343574e-01,
#        2.87053052e-01, 9.36019260e-01, 4.93427046e-01, 2.76777418e-01,
#        9.43641696e-02, 9.16744947e-01, 5.82413812e-01, 7.19195371e-01,
#        6.74409658e-02, 6.40836034e-01, 6.98392306e-01, 4.13881324e-02,
#        2.18483780e-01, 9.04044194e-01, 2.71764400e-01, 3.55910796e-01,
#        7.81482676e-01, 1.13914667e-01, 1.06386725e-01, 7.91431580e-01,
#        2.12730879e-01, 8.08990611e-01, 6.48885148e-01, 6.55445446e-01,
#        8.44560450e-01, 5.59822104e-01])
