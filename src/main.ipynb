# %%
from main import PriceSimulator

# %%
simulator = PriceSimulator(initial_price=100, mu=0.0001, sigma=0.2, dt=1, seed=4)
prices = simulator.simulate_brownian_motion_prices()
price_df = simulator.create_dataframe(prices)
simulator.plot_prices()
# Out:
# -- Generating Trading Days --
# -- Generating Time Series --
#          date      time       price  tick_by_tick_return
# 0  2023-01-02  00:00:00  100.000000             0.000000
# 1  2023-01-02  00:01:00  100.010112             0.000101
# 2  2023-01-02  00:02:00  100.110103             0.001000
# 3  2023-01-02  00:03:00   99.910921            -0.001990
# 4  2023-01-02  00:04:00  100.049641             0.001388
#               date      time      price  tick_by_tick_return
# 120955  2023-12-19  07:55:00  49.207660            -0.004885
# 120956  2023-12-19  07:56:00  49.371450             0.003329
# 120957  2023-12-19  07:57:00  49.219682            -0.003074
# 120958  2023-12-19  07:58:00  49.074095            -0.002958
# 120959  2023-12-19  07:59:00  49.479952             0.008270

# %%
price_df
# Out:
#               date      time       price  tick_by_tick_return
# 0       2023-01-02  00:00:00  100.000000             0.000000
# 1       2023-01-02  00:01:00  100.010112             0.000101
# 2       2023-01-02  00:02:00  100.110103             0.001000
# 3       2023-01-02  00:03:00   99.910921            -0.001990
# 4       2023-01-02  00:04:00  100.049641             0.001388
# ...            ...       ...         ...                  ...
# 120955  2023-12-19  07:55:00   49.207660            -0.004885
# 120956  2023-12-19  07:56:00   49.371450             0.003329
# 120957  2023-12-19  07:57:00   49.219682            -0.003074
# 120958  2023-12-19  07:58:00   49.074095            -0.002958
# 120959  2023-12-19  07:59:00   49.479952             0.008270
#
# [120960 rows x 4 columns]
